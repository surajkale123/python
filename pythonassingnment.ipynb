# %%
salary = float(input("Enter the employee's salary: ₹"))


if salary > 50000:
    category = "High Income"
elif 30000 <= salary <= 50000:
    category = "Medium Income"
else:
    category = "Low Income"


print(f"The employee belongs to the '{category}' category.")

# %%
streetlight_number = int(input("Enter the streetlight number: "))

if streetlight_number % 2 == 0:
    print("The streetlight is ON.")
else:
    print("The streetlight is OFF.")

# %%
balance = 10000  

while True:
    print("\nATM Menu:")
    print("1. Check Balance")
    print("2. Deposit Money")
    print("3. Withdraw Money")
    print("4. Exit")

    choice = int(input("Enter your choice (1-4): "))

    if choice == 1:
        print(f"Your current balance is: ₹{balance}")
    elif choice == 2:
        amount = float(input("Enter the amount to deposit: ₹"))
        balance += amount
        print(f"₹{amount} deposited. New balance: ₹{balance}")
    elif choice == 3:
        amount = float(input("Enter the amount to withdraw: ₹"))
        if amount > balance:
            print("Insufficient balance!")
        else:
            balance -= amount
            print(f"₹{amount} withdrawn. New balance: ₹{balance}")
    elif choice == 4:
        print("Exiting the ATM system. Have a great day!")
        break
    else:
        print("Invalid choice. Please select a valid option.")

# %%
total_passengers = 0

for stop in range(1, 6):
    passengers = int(input(f"Enter passengers boarding at stop {stop}: "))
    total_passengers += passengers

print(f"Total passengers in the bus: {total_passengers}")

# %%
correct_pin = 1234
attempts = 3

for _ in range(attempts):
    entered_pin = int(input("Enter your ATM PIN: "))
    if entered_pin == correct_pin:
        print("PIN Verified. Access Granted.")
        break
    else:
        print("Incorrect PIN. Try again.")
else:
    print("Too many failed attempts. Card Blocked!")

# %%
num = int(input("Enter a number: "))

reversed_num = int(str(num)[::-1])

print(f"Reversed Number: {reversed_num}")

# %%
# 7. ATM Cash Dispensing Machine
def dispense_cash(amount):
    if amount % 500 != 0:
        print("Invalid amount. Amount must be a multiple of 500.")
        return

    notes_2000 = amount // 2000
    amount %= 2000
    notes_500 = amount // 500

    print(f"₹2000 notes: {notes_2000}")
    print(f"₹500 notes: {notes_500}")

# Example usage:
# dispense_cash(12500)

# 8. Shopping Cart - List Operations
def shopping_cart():
    cart = []
    while True:
        item = input("Enter an item (or 'done' to finish): ")
        if item.lower() == "done":
            break
        cart.append(item)
    print("Shopping Cart:", cart)

# shopping_cart()

# 9. Student Grades - Tuple
def student_grades():
    grades = []
    for i in range(5):
        grade = int(input(f"Enter grade for subject {i + 1}: "))
        grades.append(grade)

    grades_tuple = tuple(grades)
    highest = max(grades_tuple)
    lowest = min(grades_tuple)
    average = sum(grades_tuple) / len(grades_tuple)

    print(f"Highest grade: {highest}")
    print(f"Lowest grade: {lowest}")
    print(f"Average grade: {average}")

# student_grades()

# 10. Movie Collection - Dictionary
def movie_collection():
    movies = {}
    while True:
        choice = input("Enter 'add', 'update', 'display', or 'exit': ")
        if choice.lower() == "add":
            title = input("Enter movie title: ")
            rating = float(input("Enter movie rating (out of 10): "))
            movies[title] = rating
        elif choice.lower() == "update":
            title = input("Enter movie title to update: ")
            if title in movies:
                rating = float(input("Enter new rating: "))
                movies[title] = rating
            else:
                print("Movie not found.")
        elif choice.lower() == "display":
            for title, rating in movies.items():
                print(f"{title}: {rating}")
        elif choice.lower() == "exit":
            break
        else:
            print("Invalid choice.")

# movie_collection()

# 11. Removing Duplicates from a List - Set
def remove_duplicates(lst):
    return list(set(lst))

# Example usage:
# book_titles = ["The Hobbit", "The Lord of the Rings", "The Hobbit", "Silmarillion"]
# unique_titles = remove_duplicates(book_titles)
# print(unique_titles)

# 12. ATM Transaction System
def check_balance(balance):
    print(f"Your balance is: ₹{balance}")

def withdraw(balance, amount):
    if amount > balance:
        print("Insufficient funds.")
        return balance
    else:
        balance -= amount
        print(f"Withdrawn ₹{amount}. Remaining balance: ₹{balance}")
        return balance

def deposit(balance, amount):
    balance += amount
    print(f"Deposited ₹{amount}. New balance: ₹{balance}")
    return balance

# Example usage:
# balance = 1000
# balance = deposit(balance, 500)
# balance = withdraw(balance, 200)
# check_balance(balance)

# 13. Student Grade Calculator
def calculate_grade(marks):
    if 90 <= marks <= 100:
        return "A"
    elif 80 <= marks <= 89:
        return "B"
    elif 70 <= marks <= 79:
        return "C"
    elif 60 <= marks <= 69:
        return "D"
    else:
        return "F"

# print(calculate_grade(85))

# 14. Simple Calculator Using Functions
def calculator(num1, num2, operator):
    if operator == "+":
        return num1 + num2
    elif operator == "-":
        return num1 - num2
    elif operator == "*":
        return num1 * num2
    elif operator == "/":
        if num2 == 0:
            return "Cannot divide by zero."
        return num1 / num2
    else:
        return "Invalid operator."

# print(calculator(5, 2, "+"))

# 15. Find the Maximum of Three Numbers
def find_max(num1, num2, num3):
    return max(num1, num2, num3)

# print(find_max(10, 5, 15))

# 16. Create a Student Class
class Student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks

    def has_passed(self):
        return self.marks >= 40

# student1 = Student("Alice", 80)
# print(student1.has_passed())

# 17. Bank Account Class
class BankAccount:
    def __init__(self, account_holder, balance):
        self.account_holder = account_holder
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount

    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient funds.")
        else:
            self.balance -= amount

# account1 = BankAccount("Bob", 1000)
# account1.deposit(500)
# account1.withdraw(200)
# print(account1.balance)

# 18. Create a Book Class
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author

    def display_details(self):
        print(f"Title: {self.title}, Author: {self.author}")

# book1 = Book("Python Crash Course", "Eric Matthes")
# book1.display_details()

# 19. Create a Rectangle Class
class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

    def perimeter(self):
        return 2 * (self.length + self.width)

# rect1 = Rectangle(5, 10)
# print(rect1.area())
# print(rect1.perimeter())

# 20. Create a Shape Class and a Derived Circle Class
import math

class Shape:
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius**2

# circle1 = Circle(5)
# print(circle1.area())

# 21. Create a Movie Class
class Movie:
    def __init__(self, title, genre, rating):
        self.title = title
        self.genre = genre
        self.rating = rating

    def display_details(self):
        print(f"Title: {self.title}, Genre: {self.genre}, Rating: {self.rating}")

# movie1 = Movie("Inception", "Sci-Fi", 8.8)
# movie1.display_details()

# 22. Student and Teacher Classes
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

class Student(Person):
    def __init__(self, name, age, grade):
        super().__init__(name, age)
        self.grade = grade

class Teacher(Person):
    def __init__(self, name, age, subject):
        super().__init__(name, age)
        self.subject = subject

# student1 = Student("Charlie", 18, 12)
# teacher1 = Teacher("David", 35, "Math")

# 23. E-Commerce Product Management
class Product:
    def __init__(self, name, price, stock):
        self.name = name
        self.price = price
        self.stock = stock

    def purchase(self, quantity):
        if self.stock >= quantity:
            self.stock -= quantity
            print(f"{quantity} {self.name}(s) purchased.")
        else:
            print("Insufficient stock.")

#
